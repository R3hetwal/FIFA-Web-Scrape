# %%
# ! pip install BeautifulSoup4
# ! pip install requests
# ! pip install lxml

# %%
url = 'https://www.foxsports.com/soccer/fifa-world-cup-men/team-stats?category=goalkeeping&sort=t_sv&season=2022&sortOrder=desc&groupId=12'

# %%
import requests

# %%
html = requests.get(url).text

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
tbody = soup.find('tbody')

# %%
table = tbody.find_all('tr')

# %%
table[0]
# Out:
# <tr><td class="cell-rank ffn-11" data-index="0"><!-- --><div class="flex-inline rank"><div class="table-indicator"></div><span class="cell-rank ffn-11 ls-pt5">1</span></div></td><td class="cell-entity fs-18 lh-1pt67" data-index="1"><!-- --><div class="table-entity"><!-- --><a class="image-logo-container cell-logo table-logo image-logo" href="/soccer/poland-men-team"><img alt="Poland" height="36" src="https://b.fssta.com/uploads/application/countries/flag-logos/616.vresize.72.72.medium.0.png" width="36"/></a><a class="table-entity-name ff-s" href="/soccer/poland-men-team">
#         Poland
#       </a><!-- --><!-- --><!-- --></div></td><td class="cell-number ff-h" data-index="2"><!-- -->
#     4
#   </td><td class="cell-number ff-h" data-index="3"><!-- -->
#     5
#   </td><td class="cell-number ff-h" data-index="4"><!-- -->
#     70
#   </td><td class="cell-number ff-h" data-index="5"><!-- -->
#     29
#   </td><td class="cell-number bold ff-h" data-index="6"><!-- -->
#     24
# ...

# %%
tds = table[0].find_all('td')

# %%
for item in range(0, len(table)):
    print(table[item])
# Out:
# <tr><td class="cell-rank ffn-11" data-index="0"><!-- --><div class="flex-inline rank"><div class="table-indicator"></div><span class="cell-rank ffn-11 ls-pt5">1</span></div></td><td class="cell-entity fs-18 lh-1pt67" data-index="1"><!-- --><div class="table-entity"><!-- --><a class="image-logo-container cell-logo table-logo image-logo" href="/soccer/poland-men-team"><img alt="Poland" height="36" src="https://b.fssta.com/uploads/application/countries/flag-logos/616.vresize.72.72.medium.0.png" width="36"/></a><a class="table-entity-name ff-s" href="/soccer/poland-men-team">
#         Poland
#       </a><!-- --><!-- --><!-- --></div></td><td class="cell-number ff-h" data-index="2"><!-- -->
#     4
#   </td><td class="cell-number ff-h" data-index="3"><!-- -->
#     5
#   </td><td class="cell-number ff-h" data-index="4"><!-- -->
#     70
#   </td><td class="cell-number ff-h" data-index="5"><!-- -->
#     29
#   </td><td class="cell-number bold ff-h" data-index="6"><!-- -->
#     24
# ...

# %%
for item in range(0, len(table)):
    tds=(table[item]).find_all('td')
    print(tds)
# Out:
# [<td class="cell-rank ffn-11" data-index="0"><!-- --><div class="flex-inline rank"><div class="table-indicator"></div><span class="cell-rank ffn-11 ls-pt5">1</span></div></td>, <td class="cell-entity fs-18 lh-1pt67" data-index="1"><!-- --><div class="table-entity"><!-- --><a class="image-logo-container cell-logo table-logo image-logo" href="/soccer/poland-men-team"><img alt="Poland" height="36" src="https://b.fssta.com/uploads/application/countries/flag-logos/616.vresize.72.72.medium.0.png" width="36"/></a><a class="table-entity-name ff-s" href="/soccer/poland-men-team">
#         Poland
#       </a><!-- --><!-- --><!-- --></div></td>, <td class="cell-number ff-h" data-index="2"><!-- -->
#     4
#   </td>, <td class="cell-number ff-h" data-index="3"><!-- -->
#     5
#   </td>, <td class="cell-number ff-h" data-index="4"><!-- -->
#     70
#   </td>, <td class="cell-number ff-h" data-index="5"><!-- -->
#     29
#   </td>, <td class="cell-number bold ff-h" data-index="6"><!-- -->
# ...

# %%
complete_data = []
for item in range(0, len(table)):
    team_data = []
    table_row = table[item]
    tds = table_row.find_all('td') # one table row has multiple table data
    for item in tds:
        team_data.append(item.text) # extract data of each team
   
    complete_data.append(team_data) # append all data of each  team on a list

# %%
clean_data = list(map(lambda x: x[1:20], complete_data))

# %%
clean_data
# Out:
# [['\n        Poland\n      ',
#   '\n    4\n  ',
#   '\n    5\n  ',
#   '\n    70\n  ',
#   '\n    29\n  ',
#   '\n    24\n  ',
#   '\n    141\n  ',
#   '\n    2\n  ',
#   '\n    2\n  ',
#   '\n    0\n  '],
#  ['\n        Croatia\n      ',
#   '\n    6\n  ',
#   '\n    6\n  ',
#   '\n    69\n  ',
#   '\n    29\n  ',
#   '\n    23\n  ',
#   '\n    194\n  ',
#   '\n    2\n  ',
#   '\n    1\n  ',
#   '\n    1\n  '],
#  ['\n        Netherlands\n      ',
#   '\n    5\n  ',
#   '\n    4\n  ',
#   '\n    63\n  ',
#   '\n    24\n  ',
#   '\n    20\n  ',
#   '\n    176\n  ',
#   '\n    2\n  ',
#   '\n    1\n  ',
#   '\n    1\n  '],
#  ['\n        Serbia\n      ',
#   '\n    3\n  ',
#   '\n    8\n  ',
#   '\n    47\n  ',
#   '\n    24\n  ',
#   '\n    16\n  ',
#   '\n    96\n  ',
#   '\n    0\n  ',
#   '\n    0\n  ',
#   '\n    0\n  '],
#  ['\n        Japan\n      ',
#   '\n    4\n  ',
#   '\n    4\n  ',
#   '\n    57\n  ',
#   '\n    19\n  ',
#   '\n    15\n  ',
#   '\n    162\n  ',
# ...

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd # as pd is alias name convention

# %%
df = pd.DataFrame(clean_data)

# %%
df
# Out:
#                                   0            1             2             3  \
# 0          \n        Poland\n        \n    4\n     \n    5\n    \n    70\n
# 1         \n        Croatia\n        \n    6\n     \n    6\n    \n    69\n
# 2     \n        Netherlands\n        \n    5\n     \n    4\n    \n    63\n
# 3          \n        Serbia\n        \n    3\n     \n    8\n    \n    47\n
# 4           \n        Japan\n        \n    4\n     \n    4\n    \n    57\n
# 5    \n        Saudi Arabia\n        \n    3\n     \n    5\n    \n    48\n
# 6       \n        Australia\n        \n    4\n     \n    6\n    \n    64\n
# 7        \n        Cameroon\n        \n    3\n     \n    4\n    \n    45\n
# 8        \n        Portugal\n        \n    5\n     \n    6\n    \n    51\n
# 9     \n        Switzerland\n        \n    4\n     \n    9\n    \n    39\n
# 10    \n        South Korea\n        \n    4\n     \n    8\n    \n    44\n
# ...

# %%
col_names = ['Teams', 
             'GP : Games Played',
             'GC : Goals Conceded',
             'S : Shots',
             'SOG : Shots On Goal',
             'SV : Saves',
             'CLR : Clearances',
             'CS : Clean Sheets',
             'PK : Penalty Kicks',
             'PKG : Penalty Kick Goals']

# %%
df.columns = col_names

# %%
df
# Out:
#                               Teams GP : Games Played GC : Goals Conceded  \
# 0          \n        Poland\n             \n    4\n           \n    5\n
# 1         \n        Croatia\n             \n    6\n           \n    6\n
# 2     \n        Netherlands\n             \n    5\n           \n    4\n
# 3          \n        Serbia\n             \n    3\n           \n    8\n
# 4           \n        Japan\n             \n    4\n           \n    4\n
# 5    \n        Saudi Arabia\n             \n    3\n           \n    5\n
# 6       \n        Australia\n             \n    4\n           \n    6\n
# 7        \n        Cameroon\n             \n    3\n           \n    4\n
# 8        \n        Portugal\n             \n    5\n           \n    6\n
# 9     \n        Switzerland\n             \n    4\n           \n    9\n
# 10    \n        South Korea\n             \n    4\n           \n    8\n
# 11        \n        Morocco\n             \n    5\n           \n    1\n
# ...

# %%
df = df.replace('\n', '', regex=True)

# %%
df
# Out:
#                           Teams GP : Games Played GC : Goals Conceded  \
# 0                  Poland                     4                   5
# 1                 Croatia                     6                   6
# 2             Netherlands                     5                   4
# 3                  Serbia                     3                   8
# 4                   Japan                     4                   4
# 5            Saudi Arabia                     3                   5
# 6               Australia                     4                   6
# 7                Cameroon                     3                   4
# 8                Portugal                     5                   6
# 9             Switzerland                     4                   9
# 10            South Korea                     4                   8
# 11                Morocco                     5                   1
# 12                Tunisia                     3                   1
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.to_csv('saves-stats-as-of-Dec14.csv', index = 'False')

# %%
filename = 'saves-stats-as-of-Dec14.csv'
saves_stats = pd.read_csv(filename)

# %%
saves_stats
# Out:
#     Unnamed: 0                        Teams  GP : Games Played  \
# 0            0                 Poland                        4
# 1            1                Croatia                        6
# 2            2            Netherlands                        5
# 3            3                 Serbia                        3
# 4            4                  Japan                        4
# 5            5           Saudi Arabia                        3
# 6            6              Australia                        4
# 7            7               Cameroon                        3
# 8            8               Portugal                        5
# 9            9            Switzerland                        4
# 10          10            South Korea                        4
# 11          11                Morocco                        5
# 12          12                Tunisia                        3
# 13          13             Costa Rica                        3
# ...
