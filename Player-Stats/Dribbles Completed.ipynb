# %%
# ! pip install BeautifulSoup4
# ! pip install requests
# ! pip install lxml

# %%
url = 'https://www.foxsports.com/soccer/fifa-world-cup-men/stats?category=control&sort=d&season=2022&sortOrder=desc&groupId=12'

# %%
import requests

# %%
html = requests.get(url).text

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
tbody = soup.find('tbody')

# %%
table = tbody.find_all('tr')

# %%
table[0]
# Out:
# <tr><td class="cell-rank ffn-11" data-index="0"><!-- --><div class="flex-inline rank"><div class="table-indicator"></div><span class="cell-rank ffn-11 ls-pt5">1</span></div></td><td class="cell-entity fs-18 lh-1pt67" data-index="1"><!-- --><div class="table-entity"><!-- --><a class="cell-logo table-logo player-headshot image-headshot" href="/soccer/kylian-mbappe-2-player"><img alt="Kylian Mbappe" height="36" src="https://b.fssta.com/uploads/application/soccer/headshots/40670.vresize.72.72.medium.91.png" width="36"/></a><a class="table-entity-name ff-s" href="/soccer/kylian-mbappe-2-player">
#         K. Mbappe
#       </a><sup class="table-superscript mg-b-5 ffn-11 ls-pt5">FRA</sup><!-- --><!-- --></div></td><td class="cell-number ff-h" data-index="2"><!-- -->
#     5
#   </td><td class="cell-number ff-h" data-index="3"><!-- -->
#     5
#   </td><td class="cell-number ff-h" data-index="4"><!-- -->
#     387
#   </td><td class="cell-number ff-h" data-index="5"><!-- -->
#     6
# ...

# %%
tds = table[0].find_all('td')

# %%
for item in range(0, len(table)):
    print(table[item])
# Out:
# <tr><td class="cell-rank ffn-11" data-index="0"><!-- --><div class="flex-inline rank"><div class="table-indicator"></div><span class="cell-rank ffn-11 ls-pt5">1</span></div></td><td class="cell-entity fs-18 lh-1pt67" data-index="1"><!-- --><div class="table-entity"><!-- --><a class="cell-logo table-logo player-headshot image-headshot" href="/soccer/kylian-mbappe-2-player"><img alt="Kylian Mbappe" height="36" src="https://b.fssta.com/uploads/application/soccer/headshots/40670.vresize.72.72.medium.91.png" width="36"/></a><a class="table-entity-name ff-s" href="/soccer/kylian-mbappe-2-player">
#         K. Mbappe
#       </a><sup class="table-superscript mg-b-5 ffn-11 ls-pt5">FRA</sup><!-- --><!-- --></div></td><td class="cell-number ff-h" data-index="2"><!-- -->
#     5
#   </td><td class="cell-number ff-h" data-index="3"><!-- -->
#     5
#   </td><td class="cell-number ff-h" data-index="4"><!-- -->
#     387
#   </td><td class="cell-number ff-h" data-index="5"><!-- -->
#     6
# ...

# %%
for item in range(0, len(table)):
    tds=(table[item]).find_all('td')
    print(tds)
# Out:
# [<td class="cell-rank ffn-11" data-index="0"><!-- --><div class="flex-inline rank"><div class="table-indicator"></div><span class="cell-rank ffn-11 ls-pt5">1</span></div></td>, <td class="cell-entity fs-18 lh-1pt67" data-index="1"><!-- --><div class="table-entity"><!-- --><a class="cell-logo table-logo player-headshot image-headshot" href="/soccer/kylian-mbappe-2-player"><img alt="Kylian Mbappe" height="36" src="https://b.fssta.com/uploads/application/soccer/headshots/40670.vresize.72.72.medium.91.png" width="36"/></a><a class="table-entity-name ff-s" href="/soccer/kylian-mbappe-2-player">
#         K. Mbappe
#       </a><sup class="table-superscript mg-b-5 ffn-11 ls-pt5">FRA</sup><!-- --><!-- --></div></td>, <td class="cell-number ff-h" data-index="2"><!-- -->
#     5
#   </td>, <td class="cell-number ff-h" data-index="3"><!-- -->
#     5
#   </td>, <td class="cell-number ff-h" data-index="4"><!-- -->
#     387
#   </td>, <td class="cell-number ff-h" data-index="5"><!-- -->
#     6
# ...

# %%
complete_data = []
for item in range(0, len(table)):
    player_data = []
    table_row = table[item]
    tds = table_row.find_all('td') # one table row has multiple table data
    for item in tds:
        player_data.append(item.text) # extract data of each player
   
    complete_data.append(player_data) # append all data of each  player on a list

# %%
clean_data = list(map(lambda x: x[1:20], complete_data))

# %%
clean_data
# Out:
# [['\n        K. Mbappe\n      FRA',
#   '\n    5\n  ',
#   '\n    5\n  ',
#   '\n    387\n  ',
#   '\n    6\n  ',
#   '\n    6\n  ',
#   '\n    .167\n  ',
#   '\n    126\n  ',
#   '\n    .894\n  ',
#   '\n    4\n  ',
#   '\n    1.000\n  ',
#   '\n    20\n  ',
#   '\n    29\n  '],
#  ['\n        L. Messi\n      ARG',
#   '\n    6\n  ',
#   '\n    6\n  ',
#   '\n    570\n  ',
#   '\n    15\n  ',
#   '\n    5\n  ',
#   '\n    .263\n  ',
#   '\n    242\n  ',
#   '\n    .877\n  ',
#   '\n    7\n  ',
#   '\n    .636\n  ',
#   '\n    19\n  ',
#   '\n    40\n  '],
#  ['\n        Neymar\n      BRA',
#   '\n    3\n  ',
#   '\n    3\n  ',
#   '\n    279\n  ',
#   '\n    3\n  ',
#   '\n    2\n  ',
#   '\n    .200\n  ',
#   '\n    116\n  ',
#   '\n    .859\n  ',
#   '\n    1\n  ',
#   '\n    .250\n  ',
#   '\n    14\n  ',
#   '\n    23\n  '],
#  ['\n        I. Sarr\n      SEN',
#   '\n    4\n  ',
#   '\n    4\n  ',
#   '\n    344\n  ',
#   '\n    6\n  ',
#   '\n    3\n  ',
#   '\n    .273\n  ',
# ...

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd # as pd is alias name convention

# %%
df = pd.DataFrame(clean_data)

# %%
df
# Out:
#                                      0            1            2   \
# 0        \n        K. Mbappe\n      FRA  \n    5\n    \n    5\n
# 1         \n        L. Messi\n      ARG  \n    6\n    \n    6\n
# 2           \n        Neymar\n      BRA  \n    3\n    \n    3\n
# 3          \n        I. Sarr\n      SEN  \n    4\n    \n    4\n
# 4          \n        D. Olmo\n      ESP  \n    4\n    \n    4\n
# 5        \n        S. Boufal\n      MAR  \n    5\n    \n    5\n
# 6        \n        A. Santos\n      BRA  \n    4\n    \n    4\n
# 7      \n        A. Di Maria\n      ARG  \n    4\n    \n    4\n
# 8       \n        J. Musiala\n      GER  \n    3\n    \n    3\n
# 9      \n        T. Buchanan\n      CAN  \n    3\n    \n    3\n
# 10       \n        V. Junior\n      BRA  \n    4\n    \n    4\n
# 11       \n        A. Davies\n      CAN  \n    3\n    \n    3\n
# 12        \n        M. Depay\n      NED  \n    5\n    \n    5\n
# 13      \n        J. Cancelo\n      POR  \n    4\n    \n    4\n
# ...

# %%
col_names = ['Players', 
             'GP : Games Played',
             'GS : Games Started', 
             'MP : Minutes Played', 
             'CC : Chances Created',
             'CS : Crosses Successful',
             'C% : Cross Percentage',
             'PC : Pass Completions',
            'P% : Pass Percentage',
            'PLC : Pass Completions - Long',
            'PLC% : Pass Percetange - Long',
            'DBC : Dribbles Completed',
            'LOP : Loss Of Posession']

# %%
df.columns = col_names

# %%
df
# Out:
#                                 Players GP : Games Played GS : Games Started  \
# 0        \n        K. Mbappe\n      FRA       \n    5\n          \n    5\n
# 1         \n        L. Messi\n      ARG       \n    6\n          \n    6\n
# 2           \n        Neymar\n      BRA       \n    3\n          \n    3\n
# 3          \n        I. Sarr\n      SEN       \n    4\n          \n    4\n
# 4          \n        D. Olmo\n      ESP       \n    4\n          \n    4\n
# 5        \n        S. Boufal\n      MAR       \n    5\n          \n    5\n
# 6        \n        A. Santos\n      BRA       \n    4\n          \n    4\n
# 7      \n        A. Di Maria\n      ARG       \n    4\n          \n    4\n
# 8       \n        J. Musiala\n      GER       \n    3\n          \n    3\n
# 9      \n        T. Buchanan\n      CAN       \n    3\n          \n    3\n
# 10       \n        V. Junior\n      BRA       \n    4\n          \n    4\n
# ...

# %%
df = df.replace('\n', '', regex=True)

# %%
df
# Out:
#                             Players GP : Games Played GS : Games Started  \
# 0                K. Mbappe      FRA               5                  5
# 1                 L. Messi      ARG               6                  6
# 2                   Neymar      BRA               3                  3
# 3                  I. Sarr      SEN               4                  4
# 4                  D. Olmo      ESP               4                  4
# 5                S. Boufal      MAR               5                  5
# 6                A. Santos      BRA               4                  4
# 7              A. Di Maria      ARG               4                  4
# 8               J. Musiala      GER               3                  3
# 9              T. Buchanan      CAN               3                  3
# 10               V. Junior      BRA               4                  4
# 11               A. Davies      CAN               3                  3
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.to_csv('dribbles_completed-stats-as-of-Dec14.csv', index = 'False')

# %%
filename = 'dribbles_completed-stats-as-of-Dec14.csv'
dribbles_completed_stats = pd.read_csv(filename)

# %%
dribbles_completed_stats
# Out:
#     Unnamed: 0                          Players  GP : Games Played  \
# 0            0               K. Mbappe      FRA                  5
# 1            1                L. Messi      ARG                  6
# 2            2                  Neymar      BRA                  3
# 3            3                 I. Sarr      SEN                  4
# 4            4                 D. Olmo      ESP                  4
# 5            5               S. Boufal      MAR                  5
# 6            6               A. Santos      BRA                  4
# 7            7             A. Di Maria      ARG                  4
# 8            8              J. Musiala      GER                  3
# 9            9             T. Buchanan      CAN                  3
# 10          10               V. Junior      BRA                  4
# 11          11               A. Davies      CAN                  3
# 12          12                M. Depay      NED                  5
# ...
